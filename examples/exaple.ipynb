# %%
import sys
import os

project_root = os.path.abspath(os.path.join("..", "ImgProcTools"))
sys.path.append(project_root)

# %%
import matplotlib.pyplot as plt

# %%
from core import image_loader
from utils import histogram_utils

# %%
def plot_image(image, title=None): 
    plt.imshow(image)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
image_path = "./images/monkey.tiff"
image = image_loader.load_image(image_path)
plot_image(image)
